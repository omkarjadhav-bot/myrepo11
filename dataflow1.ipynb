# %%
import apache_beam as beam
import logging
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def send_success_email():
    sender = 'bhagya9325@gmail.com'
    recipient = 'oj738596@gmail.com'
    subject = 'Beam Pipeline Success'
    text_body = 'The Apache Beam pipeline has completed successfully.'
    html_body = '''
    <html>
      <body>
        <h2 style="color:green;">Apache Beam Pipeline Completed</h2>
        <p>The <b>Apache Beam</b> pipeline has completed <span style="color:green;">successfully</span>.</p>
        <hr>
        <p style="font-size:12px;color:#888;">This is an automated notification.</p>
      </body>
    </html>
    '''
    msg = MIMEMultipart('alternative')
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = recipient
    part1 = MIMEText(text_body, 'plain')
    part2 = MIMEText(html_body, 'html')
    msg.attach(part1)
    msg.attach(part2)
    try:
        with smtplib.SMTP('smtp.example.com', 587) as server:
            server.starttls()
            server.login('bhagya9325@gmail.com', 'your_password')
            server.sendmail(sender, [recipient], msg.as_string())
        logger.info('Success email sent.')
    except Exception as e:
        logger.error(f'Failed to send email: {e}')

data = [1, 2, 3, 4, 5]

with beam.Pipeline() as pipeline:
    pc1 = pipeline | 'create numbers' >> beam.Create(data)
    pc2 = pc1 | 'filter data' >> beam.Filter(lambda x: x % 2 == 0)
    pc3 = pc2 | 'square' >> beam.Map(lambda x: x * x)
    pc3 | 'log result' >> beam.Map(lambda x: logger.info(f"Result: {x}"))

# Send email notification on success
send_success_email()
# Out:
# 4
# 16

# %%
import apache_beam as beam
import logging
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def send_success_email():
    sender = 'bhagya9325@gmail.com'
    recipient = 'oj738596@gmail.com'
    subject = 'Beam Pipeline Success'
    text_body = 'The Apache Beam pipeline has completed successfully.'
    html_body = '''
    <html>
      <body>
        <h2 style="color:green;">Apache Beam Pipeline Completed</h2>
        <p>The <b>Apache Beam</b> pipeline has completed <span style="color:green;">successfully</span>.</p>
        <hr>
        <p style="font-size:12px;color:#888;">This is an automated notification.</p>
      </body>
    </html>
    '''
    msg = MIMEMultipart('alternative')
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = recipient
    part1 = MIMEText(text_body, 'plain')
    part2 = MIMEText(html_body, 'html')
    msg.attach(part1)
    msg.attach(part2)
    try:
        with smtplib.SMTP('smtp.example.com', 587) as server:
            server.starttls()
            server.login('bhagya9325@gmail.com', 'your_password')
            server.sendmail(sender, [recipient], msg.as_string())
        logger.info('Success email sent.')
    except Exception as e:
        logger.error(f'Failed to send email: {e}')

pipeline = beam.Pipeline()
data = [1,2,3,4,5]

PC1 = pipeline |'create numbers' >> beam.Create(data)
PC2 = PC1 |'filter data' >> beam.Filter(lambda x:x%2==0)
PC3 = PC2 |'square'>> beam.Map(lambda x:x*x)
PC3 |'log result' >> beam.Map(lambda x: logger.info(f"Result: {x}"))

pipeline_result = pipeline.run()
pipeline_result.wait_until_finish()

# Send email notification on success
send_success_email()
# Out:
# 4
# 16
# 'DONE'

# %%
import logging
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def send_success_email():
    sender = 'bhagya9325@gmail.com'
    recipient = 'oj738596@gmail.com'
    subject = 'Task Success Notification'
    text_body = 'The Python task has completed successfully.'
    html_body = '''
    <html>
      <body>
        <h2 style="color:green;">Python Task Completed</h2>
        <p>The <b>Python</b> task has completed <span style="color:green;">successfully</span>.</p>
        <hr>
        <p style="font-size:12px;color:#888;">This is an automated notification.</p>
      </body>
    </html>
    '''
    msg = MIMEMultipart('alternative')
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = recipient
    part1 = MIMEText(text_body, 'plain')
    part2 = MIMEText(html_body, 'html')
    msg.attach(part1)
    msg.attach(part2)
    try:
        with smtplib.SMTP('smtp.example.com', 587) as server:
            server.starttls()
            server.login('bhagya9325@gmail.com', 'your_password')
            server.sendmail(sender, [recipient], msg.as_string())
        logger.info('Success email sent.')
    except Exception as e:
        logger.error(f'Failed to send email: {e}')

course = ("Pyhton","Mysql","linux")
course_duration = (30,60,45)
data = zip(course,course_duration)
logger.info(dict(data))

# Send email notification on success
send_success_email()
# Out:
# {'Pyhton': 30, 'Mysql': 60, 'linux': 45}

# %%
import logging
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def send_success_email():
    sender = 'bhagya9325@gmail.com'
    recipient = 'oj738596@gmail.com'
    subject = 'Task Success Notification'
    text_body = 'The Python task has completed successfully.'
    html_body = '''
    <html>
      <body>
        <h2 style="color:green;">Python Task Completed</h2>
        <p>The <b>Python</b> task has completed <span style="color:green;">successfully</span>.</p>
        <hr>
        <p style="font-size:12px;color:#888;">This is an automated notification.</p>
      </body>
    </html>
    '''
    msg = MIMEMultipart('alternative')
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = recipient
    part1 = MIMEText(text_body, 'plain')
    part2 = MIMEText(html_body, 'html')
    msg.attach(part1)
    msg.attach(part2)
    try:
        with smtplib.SMTP('smtp.example.com', 587) as server:
            server.starttls()
            server.login('bhagya9325@gmail.com', 'your_password')
            server.sendmail(sender, [recipient], msg.as_string())
        logger.info('Success email sent.')
    except Exception as e:
        logger.error(f'Failed to send email: {e}')

names = ("Ram","Sham")
ages = (30,45)
user_dict = dict(zip(names,ages))
logger.info(user_dict)

# Send email notification on success
send_success_email()
# Out:
# {'Ram': 30, 'Sham': 45}
